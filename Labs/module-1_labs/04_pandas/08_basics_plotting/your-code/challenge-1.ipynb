# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import math

# %% [markdown]
# #### Define your own data. We would like to have a variable callex which contains a list of numbers from 0 to 100. Furthermore, we would like a variables called y which is twice x, and a variable called z which is the square of x.

# %%
# your code here
x = list(range(0,101))
y = [i * 2 for i in x]
z = [u **2 for u in x]

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes in a line plot.
#
# #### There are 2 ways of doing this - the way we have seen in class, and also using a subplot. Please research and try both!
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here - 1st way
plt.plot(x, y)
plt.plot(x, z)
plt.show()

# %%
# your code here - 2nd way
plt.subplot(1,2,1)
plt.plot(x,y, color = 'green')
plt.title('First subplot')


plt.subplot(1,2,2)
plt.plot(x,z, color = 'red')
plt.title('Second plot')

plt.show()

# %% [markdown]
# #### Augmenting your previous code, label your axes.

# %%
# your code here
plt.xlabel('xwall')
plt.ylabel('ywall')
plt.show()

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here

a = [x^2 for x in x]
b = [math.exp(x) for x in x]
plt.plot(a,b)
plt.xscale('log')
plt.yscale('log')
plt.show()

# %% [markdown]
# ### Using DataFrames

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
df = pd.read_csv('../vehicles.csv')
df.head(2)
# Out:
#          Make              Model  Year  Engine Displacement  Cylinders  \
# 0  AM General  DJ Po Vehicle 2WD  1984                  2.5        4.0
# 1  AM General   FJ8c Post Office  1984                  4.2        6.0
#
#       Transmission     Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
# 1          25.354615        13           13            13
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550

# %%
# your code here
group1 = df.groupby(['Combined MPG'])['Highway MPG'].sum().reset_index()
# group1
plt.scatter(group1['Combined MPG'], group1['Highway MPG'])
plt.xlabel('Combined MPG')
plt.ylabel('Highway MPG')
plt.show()

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
# df.sort_values(by=['Fuel Type','City MPG'], inplace=True)
fuel = df.groupby(['Fuel Type'])['City MPG'].sum().reset_index()
fuel.plot.bar('Fuel Type',  'City MPG')
plt.show()

# %%
fuel
# Out:
#                       Fuel Type  City MPG
# 0                           CNG       958
# 1                        Diesel     19289
# 2               Gasoline or E85     18340
# 3       Gasoline or natural gas       274
# 4           Gasoline or propane        96
# 5                      Midgrade      1099
# 6                       Premium    166605
# 7    Premium Gas or Electricity       522
# 8       Premium and Electricity       498
# 9                Premium or E85      2094
# 10                      Regular    423863
# 11  Regular Gas and Electricity       690
# 12   Regular Gas or Electricity        86

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
df.hist(column='Fuel Barrels/Year')
plt.show()
