# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **pokemons**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# ### Import all required libraries

# %%
# import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import data set
#
# Import data set `Pokemon.csv` from the `your-code` directory of this lab. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import data set
pokemon = pd.read_csv('Pokemon.csv')

# %% [markdown]
# ### Print first 10 rows of `pokemon`

# %%
# enter your code here
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# ### Obtain the distinct values across `Type 1` and `Type 2`
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
# enter your code here
type_1_2 =  (pokemon['Type 1'].append(pokemon['Type 2'])).unique()
type_1_2
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying', nan], dtype=object)

# %%
#for one column
unique_values = pokemon['Type 1'].unique()
unique_values
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %% [markdown]
# ### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# enter your code here
pokemon['A/D Ratio'] = pokemon['Attack'] // pokemon['Defense']
pokemon.head(2)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
#
#    Speed  Generation  Legendary  A/D Ratio
# 0     45           1      False          1
# 1     60           1      False          0

# %% [markdown]
# ### Identify the pokemon with the highest `A/D Ratio`

# %%
# enter your code here   
pokemon[pokemon['A/D Ratio']== pokemon['A/D Ratio'].max()]
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic    NaN    600  50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 429      180       20    150           3       True          9

# %% [markdown]
# ### Identify the pokemon with the lowest  `A/D Ratio`

# %%
# enter your code here
pokemon[pokemon['A/D Ratio']== pokemon['A/D Ratio'].min()].head()
# Out:
#     #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 1   2                Ivysaur  Grass  Poison    405  60      62       63
# 2   3               Venusaur  Grass  Poison    525  80      82       83
# 3   3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 9   7               Squirtle  Water     NaN    314  44      48       65
# 10  8              Wartortle  Water     NaN    405  59      63       80
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 1        80       80     60           1      False          0
# 2       100      100     80           1      False          0
# 3       122      120     80           1      False          0
# 9        50       64     43           1      False          0
# 10       65       80     58           1      False          0

# %% [markdown]
# ### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values (not NaN), the `Combo Type` value should contain both values in the form of `<Type 1>-<Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`. You do not need to check for cases the other way round, those are the only two options.
#
# To solve this challenge, you will need to write a function which combines values from the rows, and then apply it to the dataframe (using df.apply, like we learned in the map-filter-reduce chapter)!

# %%
pokemon['Type 1'] + '-'+pokemon['Type 2']
# Out:
# 0       Grass-Poison
# 1       Grass-Poison
# 2       Grass-Poison
# 3       Grass-Poison
# 4                NaN
#            ...
# 795       Rock-Fairy
# 796       Rock-Fairy
# 797    Psychic-Ghost
# 798     Psychic-Dark
# 799       Fire-Water
# Length: 800, dtype: object

# %%
def add_combo_type(row):
    if pd.isnull(row['Type 1']): pandas.isnull(obj). #detect missing valuesfor an array-like objest.
        return row['Type 1']
    return ''.([row])

# %%
# enter your code here
def join_types(x):
    if pd.isnull(x['Type 2']):
        return x['Type 1']
    else:
        return '-'.join([x['Type 1'],x['Type 2']])
pokemon['Combo Type'] = pokemon.apply(join_types,axis=1)

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio     Combo Type
# 0         65       65     45           1      False          1   Grass-Poison
# 1         80       80     60           1      False          0   Grass-Poison
# 2        100      100     80           1      False          0   Grass-Poison
# 3        122      120     80           1      False          0   Grass-Poison
# 4         60       50     65           1      False          1           Fire
# ..       ...      ...    ...         ...        ...        ...            ...
# 795      100      150     50           6       True          0     Rock-Fairy
# 796      160      110    110           6       True          1     Rock-Fairy
# 797      150      130     70           6       True          1  Psychic-Ghost
# 798      170      130     80           6       True          2   Psychic-Dark
# 799      130       90     70           6       True          0     Fire-Water
#
# [800 rows x 15 columns]

# %% [markdown]
# ### Identify the pokemons whose `A/D Ratio` are among the top 5

# %%
# enter your code here
pokemon.nlargest(5,'A/D Ratio')
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386     DeoxysAttack Forme  Psychic     NaN    600  50     180       20
# 347  318               Carvanha    Water    Dark    305  45      90       20
# 19    15  BeedrillMega Beedrill      Bug  Poison    495  65     150       40
# 348  319               Sharpedo    Water    Dark    460  70     120       40
# 428  386     DeoxysNormal Forme  Psychic     NaN    600  50     150       50
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 429      180       20    150           3       True          9
# 347       65       20     65           3      False          4
# 19        15       80    145           1      False          3
# 348       95       40     95           3      False          3
# 428      150       50    150           3       True          3

# %% [markdown]
# ### Calculate the aggregated Attack and Defense for each of the Combo Type.

# %%
# enter your code here
pokemon.groupby(['Combo Type'])['Attack', 'Defense'].sum().reset_index()
# Out:
# <ipython-input-63-5fd7693f9a5e>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   pokemon.groupby(['Combo Type'])['Attack', 'Defense'].sum().reset_index()
#         Combo Type  Attack  Defense
# 0              Bug     856      942
# 1     Bug-Electric     124      110
# 2     Bug-Fighting     310      190
# 3         Bug-Fire     145      120
# 4       Bug-Flying     982      862
# ..             ...     ...      ...
# 149      Water-Ice     250      340
# 150   Water-Poison     205      175
# 151  Water-Psychic     365      520
# 152     Water-Rock     331      451
# 153    Water-Steel      86       88
#
# [154 rows x 3 columns]

# %% [markdown]
# ### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemons.
#
# Your output should look like below:
#
# ![Aggregate](aggregated-mean.png)

# %%
# enter your code here
pokemon.groupby('Combo Type').mean().reset_index()
# Out:
#         Combo Type           #       Total         HP      Attack     Defense  \
# 0              Bug  361.352941  289.705882  53.058824   50.352941   55.411765
# 1     Bug-Electric  595.500000  395.500000  60.000000   62.000000   55.000000
# 2     Bug-Fighting  214.000000  550.000000  80.000000  155.000000   95.000000
# 3         Bug-Fire  636.500000  455.000000  70.000000   72.500000   60.000000
# 4       Bug-Flying  286.285714  419.500000  63.000000   70.142857   61.571429
# ..             ...         ...         ...        ...         ...         ...
# 149      Water-Ice  103.000000  511.666667  90.000000   83.333333  113.333333
# 150   Water-Poison  118.666667  426.666667  61.666667   68.333333   58.333333
# 151  Water-Psychic  111.800000  481.000000  87.000000   73.000000  104.000000
# 152     Water-Rock  430.000000  428.750000  70.750000   82.750000  112.750000
# 153    Water-Steel  395.000000  530.000000  84.000000   86.000000   88.000000
#
#         Sp. Atk     Sp. Def      Speed  Generation  Legendary  A/D Ratio
# 0     39.294118   43.647059  47.941176    3.470588        0.0   0.352941
# 1     77.000000   55.000000  86.500000    5.000000        0.0   0.500000
# 2     40.000000  100.000000  80.000000    2.000000        0.0   1.000000
# 3     92.500000   80.000000  80.000000    5.000000        0.0   0.500000
# 4     72.857143   69.071429  82.857143    2.857143        0.0   0.571429
# ..          ...         ...        ...         ...        ...        ...
# 149   80.000000   78.333333  66.666667    1.000000        0.0   0.333333
# 150   61.666667   91.666667  85.000000    1.333333        0.0   1.000000
# 151   94.000000   79.000000  44.000000    1.200000        0.0   0.200000
# 152   61.500000   65.000000  36.000000    3.750000        0.0   0.000000
# 153  111.000000  101.000000  60.000000    4.000000        0.0   0.000000
#
# [154 rows x 12 columns]
