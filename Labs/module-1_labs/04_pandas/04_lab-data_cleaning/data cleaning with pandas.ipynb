# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('vehicles.csv')

# %%
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %%
df.values
# Out:
# array([['AM General', 'DJ Po Vehicle 2WD', 1984, ..., 17,
#         522.7647058823529, 1950],
#        ['AM General', 'FJ8c Post Office', 1984, ..., 13,
#         683.6153846153846, 2550],
#        ['AM General', 'Post Office DJ5 2WD', 1985, ..., 16, 555.4375,
#         2100],
#        ...,
#        ['smart', 'fortwo coupe', 2015, ..., 36, 244.0, 1100],
#        ['smart', 'fortwo coupe', 2016, ..., 36, 246.0, 1100],
#        ['smart', 'fortwo coupe', 2016, ..., 35, 255.0, 1150]],
#       dtype=object)

# %%
#renaming of column or columns
df.rename(columns={'Make':'manufacturer'}, inplace=True)
df.rename(columns={'Make':'manufacturer', 'Engine Displacement' : 'displacement'}, inplace=True)

# %% [markdown]
# # FILTERING DATA

# %%
df[df['manufacturer']=='Ford']
# Out:
#       manufacturer               Model  Year  displacement  Cylinders  \
# 11440         Ford        Aerostar Van  1986           2.3        4.0
# 11441         Ford        Aerostar Van  1986           2.3        4.0
# 11442         Ford        Aerostar Van  1986           2.8        6.0
# 11443         Ford        Aerostar Van  1986           2.8        6.0
# 11444         Ford        Aerostar Van  1986           3.0        6.0
# ...            ...                 ...   ...           ...        ...
# 14381         Ford  Windstar FWD Wagon  2000           3.0        6.0
# 14382         Ford  Windstar FWD Wagon  2000           3.8        6.0
# 14383         Ford  Windstar FWD Wagon  2001           3.8        6.0
# 14384         Ford  Windstar FWD Wagon  2002           3.8        6.0
# 14385         Ford  Windstar FWD Wagon  2003           3.8        6.0
#
#           Transmission         Drivetrain  Vehicle Class Fuel Type  \
# ...

# %%
#GIVING IT A NEW VARABLE

# %%
# the two statement has to be in separate parenthesis and the two statement have to be in one bracket
df_ford_1986 = df[(df['manufacturer']=='Ford') & (df['Year']==1986)]
df_ford_1986.head(2)
# Out:
#       manufacturer         Model  Year  displacement  Cylinders  \
# 11440         Ford  Aerostar Van  1986           2.3        4.0
# 11441         Ford  Aerostar Van  1986           2.3        4.0
#
#           Transmission        Drivetrain Vehicle Class Fuel Type  \
# 11440  Automatic 4-spd  Rear-Wheel Drive          Vans   Regular
# 11441     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 11440          17.347895        18           22            19
# 11441          13.733750        23           26            24
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year
# 11440               467.736842            1750
# 11441               370.291667            1400

# %%
#creating of new column with aggregate
df['age'] = 2020 - df['Year']
df.head(2)
# Out:
#   manufacturer              Model  Year  displacement  Cylinders  \
# 0   AM General  DJ Po Vehicle 2WD  1984           2.5        4.0
# 1   AM General   FJ8c Post Office  1984           4.2        6.0
#
#       Transmission     Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
# 1          25.354615        13           13            13
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year  age
# 0               522.764706            1950   36
# 1               683.615385            2550   36

# %% [markdown]
# # Applying functions to columns

# %%
df.sum()
# Out:
# manufacturer               AM GeneralAM GeneralAM GeneralAM GeneralASC In...
# Model                      DJ Po Vehicle 2WDFJ8c Post OfficePost Office D...
# Year                                                                71929756
# displacement                                                          120026
# Cylinders                                                             207266
# Transmission               Automatic 3-spdAutomatic 3-spdAutomatic 3-spdA...
# Drivetrain                 2-Wheel Drive2-Wheel DriveRear-Wheel DriveRear...
# Vehicle Class              Special Purpose Vehicle 2WDSpecial Purpose Veh...
# Fuel Type                  RegularRegularRegularRegularPremiumRegularRegu...
# Fuel Barrels/Year                                                     633081
# City MPG                                                              634414
# Highway MPG                                                           858557
# ...

# %%
df.sum(axis =1)
# Out:
# 0        4570.653529
# 1        5328.170000
# 2        4751.538125
# 3        5328.170000
# 4        5206.838125
#             ...
# 35947    3485.155833
# 35948    3484.155833
# 35949    3485.155833
# 35950    3488.055833
# 35951    3544.317429
# Length: 35952, dtype: float64

# %%
# Droping two columns
df = df.drop(['Highway MPG', 'Fuel Type'], axis =1)

# %%
df['2020'] = df['age'] + df['Year']
df.head(2)
# Out:
#   manufacturer              Model  Year  displacement  Cylinders  \
# 0   AM General  DJ Po Vehicle 2WD  1984           2.5        4.0
# 1   AM General   FJ8c Post Office  1984           4.2        6.0
#
#       Transmission     Drivetrain                Vehicle Class  \
# 0  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD
# 1  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD
#
#    Fuel Barrels/Year  City MPG  Combined MPG  CO2 Emission Grams/Mile  \
# 0          19.388824        18            17               522.764706
# 1          25.354615        13            13               683.615385
#
#    Fuel Cost/Year  age  2020
# 0            1950   36  2020
# 1            2550   36  2020

# %%
# To delete or to drop column from a dataframe
#del df['displacenew']

# %%
''' Let's say we want to take a sum of all numeric columns in the animals DataFrame. We can do this by 
using the sum function and passing axis=1as an argument to the function. '''
yes= df.sum(axis = 1)
yes.head()
# Out:
# 0    6573.653529
# 1    7335.170000
# 2    6754.538125
# 3    7335.170000
# 4    7205.838125
# dtype: float64

# %%
# sum of rows
row = df.sum(axis = 0)
row
# Out:
# manufacturer               AM GeneralAM GeneralAM GeneralAM GeneralASC In...
# Model                      DJ Po Vehicle 2WDFJ8c Post OfficePost Office D...
# Year                                                                71929756
# displacement                                                          120026
# Cylinders                                                             207266
# Transmission               Automatic 3-spdAutomatic 3-spdAutomatic 3-spdA...
# Drivetrain                 2-Wheel Drive2-Wheel DriveRear-Wheel DriveRear...
# Vehicle Class              Special Purpose Vehicle 2WDSpecial Purpose Veh...
# Fuel Barrels/Year                                                     633081
# City MPG                                                              634414
# Combined MPG                                                          716499
# CO2 Emission Grams/Mile                                          1.70886e+07
# ...

# %%
# Getting sum of a column
df[['Year', 'City MPG']].sum()
# Out:
# Year        71929756
# City MPG      634414
# dtype: int64

# %%
# Calling out columns
df[['Year', 'City MPG']]
# Out:
#        Year  City MPG
# 0      1984        18
# 1      1984        13
# 2      1985        16
# 3      1985        13
# 4      1987        14
# ...     ...       ...
# 35947  2013        34
# 35948  2014        34
# 35949  2015        34
# 35950  2016        34
# 35951  2016        32
#
# [35952 rows x 2 columns]

# %%
# sorting columns by ascending or descending     if you want asc then  u. have to assign Ascending = True
df.sort_values(by = 'Year', inplace =True, ascending = True)
df = df.sort_values(by =  'Year')
df.head()
# Out:
#       manufacturer              Model  Year  displacement  Cylinders  \
# 0       AM General  DJ Po Vehicle 2WD  1984           2.5        4.0
# 26753       Nissan         Pickup 2WD  1984           2.4        4.0
# 26752       Nissan         Pickup 2WD  1984           2.0        4.0
# 31002       Subaru           Brat 4WD  1984           1.8        4.0
# 31003       Subaru           Brat 4WD  1984           1.8        4.0
#
#           Transmission                  Drivetrain  \
# 0      Automatic 3-spd               2-Wheel Drive
# 26753  Automatic 3-spd               2-Wheel Drive
# 26752     Manual 5-spd               2-Wheel Drive
# 31002  Automatic 3-spd  4-Wheel or All-Wheel Drive
# 31003     Manual 4-spd  4-Wheel or All-Wheel Drive
#
#                      Vehicle Class  Fuel Barrels/Year  City MPG  Combined MPG  \
# 0      Special Purpose Vehicle 2WD          19.388824        18            17
# 26753      Small Pickup Trucks 2WD          17.347895        18            19
# ...

# %%
# Getting the largest value from a column
df.nlargest(3, 'Year')
# Out:
#      manufacturer              Model  Year  displacement  Cylinders  \
# 2635          BMW        M240i Coupe  2017           3.0        6.0
# 2634          BMW        M240i Coupe  2017           3.0        6.0
# 2633          BMW  M240i Convertible  2017           3.0        6.0
#
#         Transmission        Drivetrain    Vehicle Class  Fuel Barrels/Year  \
# 2635    Manual 6-spd  Rear-Wheel Drive  Subcompact Cars          14.982273
# 2634  Automatic (S8)  Rear-Wheel Drive  Subcompact Cars          13.184400
# 2633    Manual 6-spd  Rear-Wheel Drive  Subcompact Cars          14.330870
#
#       City MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year  age  \
# 2635        19            22                    401.0            1850    3
# 2634        21            25                    358.0            1600    3
# 2633        19            23                    395.0            1750    3
#
#       2020
# 2635  2020
# 2634  2020
# 2633  2020

# %%
# Getting the largest value from MORE THAN ONE column
df.nlargest(3,[ 'Year', 'City MPG', 'Combined MPG'])
# Out:
#       manufacturer          Model  Year  displacement  Cylinders  \
# 33280       Toyota      Prius Eco  2017           1.8        4.0
# 33278       Toyota          Prius  2017           1.8        4.0
# 17058        Honda  Accord Hybrid  2017           2.0        4.0
#
#                            Transmission         Drivetrain Vehicle Class  \
# 33280  Automatic (variable gear ratios)  Front-Wheel Drive  Midsize Cars
# 33278  Automatic (variable gear ratios)  Front-Wheel Drive  Midsize Cars
# 17058  Automatic (variable gear ratios)  Front-Wheel Drive  Midsize Cars
#
#        Fuel Barrels/Year  City MPG  Combined MPG  CO2 Emission Grams/Mile  \
# 33280           5.885893        58            56                    158.0
# 33278           6.338654        54            52                    171.0
# 17058           6.866875        49            48                    183.0
#
#        Fuel Cost/Year  age  2020
# 33280             600    3  2020
# 33278             650    3  2020
# ...

# %%
df.nsmallest(3,['Year', 'City MPG'])
# Out:
#       manufacturer                        Model  Year  displacement  \
# 9068         Dodge               B350 Wagon 2WD  1984           5.9
# 9716         Dodge  D250 Pickup Cab Chassis 2WD  1984           5.9
# 10974        Dodge              W250 Pickup 4WD  1984           5.9
#
#        Cylinders     Transmission                  Drivetrain  \
# 9068         8.0  Automatic 3-spd               2-Wheel Drive
# 9716         8.0  Automatic 3-spd               2-Wheel Drive
# 10974        8.0  Automatic 3-spd  4-Wheel or All-Wheel Drive
#
#                     Vehicle Class  Fuel Barrels/Year  City MPG  Combined MPG  \
# 9068         Vans, Passenger Type          36.623333         8             9
# 9716     Special Purpose Vehicles          32.961000         9            10
# 10974  Standard Pickup Trucks 4WD          32.961000         9            10
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year  age  2020
# 9068                987.444444            3700   36  2020
# ...

# %%
df.mean()
# Out:
# Year                       2000.716400
# displacement                  3.338493
# Cylinders                     5.765076
# Fuel Barrels/Year            17.609056
# City MPG                     17.646139
# Combined MPG                 19.929322
# CO2 Emission Grams/Mile     475.316339
# Fuel Cost/Year             1892.598465
# age                          19.283600
# 2020                       2020.000000
# dtype: float64

# %%
# to get the upper letters for columns,you have to str before upper 
df['manufacturer'].str.upper()
df['manufacturer'].apply(str.upper)
# Out:
# 0           AM GENERAL
# 26753           NISSAN
# 26752           NISSAN
# 31002           SUBARU
# 31003           SUBARU
#              ...
# 24109    MERCEDES-BENZ
# 851               AUDI
# 24108    MERCEDES-BENZ
# 14410              GMC
# 20450              KIA
# Name: manufacturer, Length: 35952, dtype: object

# %%
# using lambda to turn values in column to upper case
df['manufacturer'].apply(lambda x : x.upper())
# Out:
# 0           AM GENERAL
# 26753           NISSAN
# 26752           NISSAN
# 31002           SUBARU
# 31003           SUBARU
#              ...
# 24109    MERCEDES-BENZ
# 851               AUDI
# 24108    MERCEDES-BENZ
# 14410              GMC
# 20450              KIA
# Name: manufacturer, Length: 35952, dtype: object

# %%
df['manufacturer'].apply(lambda x: x.replace('a', 'b'))
# Out:
# 0           AM Generbl
# 26753           Nissbn
# 26752           Nissbn
# 31002           Subbru
# 31003           Subbru
#              ...
# 24109    Mercedes-Benz
# 851               Audi
# 24108    Mercedes-Benz
# 14410              GMC
# 20450              Kib
# Name: manufacturer, Length: 35952, dtype: object

# %%
df.columns
# Out:
# Index(['manufacturer', 'Model', 'Year', 'displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Barrels/Year',
#        'City MPG', 'Combined MPG', 'CO2 Emission Grams/Mile', 'Fuel Cost/Year',
#        'age', '2020'],
#       dtype='object')

# %%
df.groupby(['Year']).mean().reset_index().head()
# Out:
#    Year  displacement  Cylinders  Fuel Barrels/Year   City MPG  Combined MPG  \
# 0  1984      3.927752   6.102326          21.185192  15.485271     16.844961
# 1  1985      3.170462   5.388362          18.090052  17.872233     19.805187
# 2  1986      3.184764   5.430976          18.201528  17.675926     19.562290
# 3  1987      3.138815   5.384808          18.373926  17.414858     19.349750
# 4  1988      3.201698   5.469169          18.311235  17.321716     19.315460
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year   age    2020
# 0               570.355997     2125.891473  36.0  2020.0
# 1               487.234897     1840.101202  35.0  2020.0
# 2               490.418652     1859.343434  34.0  2020.0
# 3               495.114201     1881.886477  33.0  2020.0
# 4               493.516114     1885.701519  32.0  2020.0

# %%
df.describe()
# Out:
#               Year  displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000  35952.000000  35952.000000       35952.000000
# mean    2000.71640      3.338493      5.765076          17.609056
# std       10.08529      1.359395      1.755268           4.467283
# min     1984.00000      0.600000      2.000000           0.060000
# 25%     1991.00000      2.200000      4.000000          14.699423
# 50%     2001.00000      3.000000      6.000000          17.347895
# 75%     2010.00000      4.300000      6.000000          20.600625
# max     2017.00000      8.400000     16.000000          47.087143
#
#            City MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year  \
# count  35952.000000  35952.000000             35952.000000    35952.000000
# mean      17.646139     19.929322               475.316339     1892.598465
# std        4.769349      5.112409               119.060773      506.958627
# ...

# %%
df.columns
# Out:
# Index(['manufacturer', 'Model', 'Year', 'displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Barrels/Year',
#        'City MPG', 'Combined MPG', 'CO2 Emission Grams/Mile', 'Fuel Cost/Year',
#        'age', '2020'],
#       dtype='object')

# %%
df.groupby(['manufacturer'])['displacement', 'age', 'Fuel Cost/Year'].sum().reset_index()
# Out:
#                     manufacturer  displacement    age  Fuel Cost/Year
# 0                     AM General          13.4    142            9150
# 1               ASC Incorporated           3.8     33            2550
# 2                          Acura         856.1   4985          559450
# 3                     Alfa Romeo         104.8   1153           80450
# 4    American Motors Corporation          83.9    779           41650
# ..                           ...           ...    ...             ...
# 122                   Volkswagen        2341.1  17874         1653650
# 123                        Volvo        1795.9  12775         1299400
# 124        Wallace Environmental         138.1    912           95900
# 125                         Yugo           9.6    253           10800
# 126                        smart          19.6    150           22200
#
# [127 rows x 4 columns]

# %%
df.groupby(['manufacturer', 'Model','Combined MPG'])['displacement','Fuel Barrels/Year'].median().reset_index()
# Out:
#           manufacturer                Model  Combined MPG  displacement  \
# 0           AM General    DJ Po Vehicle 2WD            17           2.5
# 1           AM General     FJ8c Post Office            13           4.2
# 2           AM General  Post Office DJ5 2WD            16           2.5
# 3           AM General  Post Office DJ8 2WD            13           4.2
# 4     ASC Incorporated                  GNX            16           3.8
# ...                ...                  ...           ...           ...
# 9676             smart     fortwo cabriolet            35           0.9
# 9677             smart     fortwo cabriolet            36           1.0
# 9678             smart   fortwo convertible            36           1.0
# 9679             smart         fortwo coupe            35           0.9
# 9680             smart         fortwo coupe            36           1.0
#
#       Fuel Barrels/Year
# 0             19.388824
# 1             25.354615
# 2             20.600625
# ...

# %%
#Here we produce the mean, median and standard deviation for combined MPG grouped by fuel type
df.groupby(['manufacturer'])['displacement', 'Combined MPG'].agg(['mean', 'median','sum', 'std']).reset_index()
# Out:
#                     manufacturer displacement                           \
#                                          mean median     sum       std
# 0                     AM General     3.350000   3.35    13.4  0.981495
# 1               ASC Incorporated     3.800000   3.80     3.8       NaN
# 2                          Acura     2.834768   3.00   856.1  0.672588
# 3                     Alfa Romeo     2.556098   2.50   104.8  0.568792
# 4    American Motors Corporation     3.813636   4.20    83.9  0.729184
# ..                           ...          ...    ...     ...       ...
# 122                   Volkswagen     2.236008   2.00  2341.1  0.599835
# 123                        Volvo     2.504742   2.40  1795.9  0.383063
# 124        Wallace Environmental     4.315625   4.90   138.1  1.382170
# 125                         Yugo     1.200000   1.20     9.6  0.106904
# 126                        smart     0.980000   1.00    19.6  0.041039
#
#     Combined MPG
# ...

# %%
# how to remove characters from column and all of dataframe
 '''df['name']  = df['name'].str.replace(r'\W', "") this will remove all characters in the column(name) that are not 
 number and letter and replace them with empty string '''
''' for column in df.columns:
    df[column] = df[column].str.replace(r'\W', "") this will remove all the characters from the dataframe that are 
    not numbers and letters and replace them with emoty string '''
# Out:
#   File "<ipython-input-59-3a66a1801648>", line 2
#     '''df['name']  = df['name'].str.replace(r'\W', "") this will remove all characters in the column(name) that are not
#     ^
# IndentationError: unexpected indent

# %%
filtered = df[(df['manufacturer']=='Ford') & 
                (df['Cylinders']>=6) | 
                (df['Combined MPG'] < 18)]
#filtered

# %%
''' You will also notice that in some cases Automatic is abbreviated to Auto and in other cases it is spelled out.
We can make that more consistent by using the same technique. While we are at it, let's also attempt to remove 
parentheses and make spacing more consistent.'''
data['trany'] = data['trany'].str.replace('Automatic', 'Auto')
data['trany'] = data['trany'].str.replace('Auto\(', 'Auto ')
data['trany'] = data['trany'].str.replace('Manual\(', 'Manual ')
data['trany'] = data['trany'].str.replace('\(', '')
data['trany'] = data['trany'].str.replace('\)', '')
print(set(data['trany']))

# %%
data = list(zip([2000]*4, ['q1', 'q2', 'q3', 'q4']))
data
# Out:
# [(2000, 'q1'), (2000, 'q2'), (2000, 'q3'), (2000, 'q4')]

# %%
# to get numeric columns from a dataframe ._get_numeric_data()
df._get_numeric_data().head()
# Out:
#        Year  displacement  Cylinders  Fuel Barrels/Year  City MPG  \
# 0      1984           2.5        4.0          19.388824        18
# 26753  1984           2.4        4.0          17.347895        18
# 26752  1984           2.0        4.0          12.207778        24
# 31002  1984           1.8        4.0          15.695714        20
# 31003  1984           1.8        4.0          13.733750        22
#
#        Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year  age  2020
# 0                17               522.764706            1950   36  2020
# 26753            19               467.736842            1750   36  2020
# 26752            27               329.148148            1250   36  2020
# 31002            21               423.190476            1600   36  2020
# 31003            24               370.291667            1400   36  2020

# %%
# getting the column's names that are numeric
cols = df.select_dtypes([np.number]).columns
cols
# Out:
# Index(['Year', 'displacement', 'Cylinders', 'Fuel Barrels/Year', 'City MPG',
#        'Combined MPG', 'CO2 Emission Grams/Mile', 'Fuel Cost/Year', 'age',
#        '2020'],
#       dtype='object')

# %%
df.select_dtypes(np.number).head()
# Out:
#        Year  displacement  Cylinders  Fuel Barrels/Year  City MPG  \
# 0      1984           2.5        4.0          19.388824        18
# 26753  1984           2.4        4.0          17.347895        18
# 26752  1984           2.0        4.0          12.207778        24
# 31002  1984           1.8        4.0          15.695714        20
# 31003  1984           1.8        4.0          13.733750        22
#
#        Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year  age  2020
# 0                17               522.764706            1950   36  2020
# 26753            19               467.736842            1750   36  2020
# 26752            27               329.148148            1250   36  2020
# 31002            21               423.190476            1600   36  2020
# 31003            24               370.291667            1400   36  2020

# %%
df.select_dtypes(float).head()
# Out:
#        displacement  Cylinders  Fuel Barrels/Year  CO2 Emission Grams/Mile
# 0               2.5        4.0          19.388824               522.764706
# 26753           2.4        4.0          17.347895               467.736842
# 26752           2.0        4.0          12.207778               329.148148
# 31002           1.8        4.0          15.695714               423.190476
# 31003           1.8        4.0          13.733750               370.291667

# %%
# getting columns from  dataframe exclude numeric columns
df.select_dtypes(exclude =np.number).head()
# Out:
#       manufacturer              Model     Transmission  \
# 0       AM General  DJ Po Vehicle 2WD  Automatic 3-spd
# 26753       Nissan         Pickup 2WD  Automatic 3-spd
# 26752       Nissan         Pickup 2WD     Manual 5-spd
# 31002       Subaru           Brat 4WD  Automatic 3-spd
# 31003       Subaru           Brat 4WD     Manual 4-spd
#
#                        Drivetrain                Vehicle Class
# 0                   2-Wheel Drive  Special Purpose Vehicle 2WD
# 26753               2-Wheel Drive      Small Pickup Trucks 2WD
# 26752               2-Wheel Drive      Small Pickup Trucks 2WD
# 31002  4-Wheel or All-Wheel Drive  Special Purpose Vehicle 4WD
# 31003  4-Wheel or All-Wheel Drive  Special Purpose Vehicle 4WD

# %%
df.columns
# Out:
# Index(['manufacturer', 'Model', 'Year', 'displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Barrels/Year',
#        'City MPG', 'Combined MPG', 'CO2 Emission Grams/Mile', 'Fuel Cost/Year',
#        'age', '2020'],
#       dtype='object')

# %%
vehicles_mean = df[[ "City MPG", "Drivetrain"]].groupby(["Drivetrain"]).agg("mean")
vehicles_mean.plot.bar()
plt.show()
