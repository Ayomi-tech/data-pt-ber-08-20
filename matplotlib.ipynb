# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
x = [1, 2, 3, 4, 5]
y = [1, 2, 3, 4, 5]

#plt.plot(x, y, 'dg') # u can write the color together with the type of plot u want but its nice to seperate it
# your series must have the same lenght
plt.plot(x, y, 'd', color = 'red')
plt.title('This is a plot')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()

# %% [markdown]
# # plotting multiple series

# %%
# line plot
z = [5, 4, 3, 2, 1]
plt.plot(x, y, color = 'magenta')
plt.plot(x, z, color = 'yellow', linewidth = 5)
plt.legend(['kitty','cat'])
plt.show()

# %% [markdown]
# # Scatter plot

# %%
a = np.random.random(10)
b = np.random.random(10)

plt.scatter(a, b, color = 'green')
plt.xlabel('A')
plt.ylabel('B')
plt.show()

# %% [markdown]
# # Pie charts

# %%
animals = ['Cat', 'Dogs', 'Hamster']
values = [20, 30, 50]

plt.pie(values, labels = animals, colors = ['yellow', 'blue', 'green'])
plt.show()

# %% [markdown]
# # Bar chart

# %%
plt.bar(animals, height = values) # we use height cos we need to assign what our bar should carry(bar is also height)
plt.show()

# %%
plt.barh(animals, width = values) #we use width cos we are plotting to the side
plt.show()

# %%
x1 = np.arange(0,10,1)
x2 = np.linspace(0,5,10)
plt.scatter(x1, x2)
plt.show()

# %%
df = pd.read_csv('vehicles.csv')
df.head(2)
# Out:
#          Make              Model  Year  Engine Displacement  Cylinders  \
# 0  AM General  DJ Po Vehicle 2WD  1984                  2.5        4.0
# 1  AM General   FJ8c Post Office  1984                  4.2        6.0
#
#       Transmission     Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
# 1          25.354615        13           13            13
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550

# %%
df.sort_values(by=['City MPG','Highway MPG' ], inplace=True)
plt.plot(df['City MPG'],df['Highway MPG'])
plt.show()

# %%
df.plot(x = 'City MPG', y='Highway MPG' )
plt.show()

# %%
group=df[['City MPG', 'Year']].groupby(['Year']).mean().reset_index()
group
group.plot(x = 'Year', y= 'City MPG')        #we use group to plot because it carring our aggregation.
plt.show()

# %%
# you can also plot by plt because we have to include the variable of your aggregation code and we have to specify the x and y 
plt.plot(group['Year'], group['City MPG'])
plt.show()

# %% [markdown]
# # multiple line plot: average City MPG and Highway MPG by year

# %%
group2 = df[['City MPG','Highway MPG', 'Year']].groupby(['Year']).mean().reset_index()
plt.plot(group2['Year'], group2[['City MPG','Highway MPG']])
plt.show()

# %%
group2.plot.bar(x ='Year', y = ['City MPG','Highway MPG'])
plt.show()

# %%
group2 = df.groupby(['Year'])[['City MPG','Highway MPG', 'Combined MPG']].mean().reset_index()
plt.plot(group2['Year'], group2[['City MPG','Highway MPG', 'Combined MPG']])
plt.show()

# %%
group2.plot.bar(x ='Year', y = ['City MPG','Highway MPG','Combined MPG'])
plt.show()

# %% [markdown]
# # VISUALIZATION with SEABORN

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_palette('husl')

# %% [markdown]
# boxplot - give idea of what you have in your dataset, like the percentile, mode, median
# and mean, outliers. shows how spread out the dataset is.
#
# Violin plot -it shows us where excatly the max,  mean,  interquartilerange and 1.5x interuatile is in our dataset.
# white dot shows the median.makes it easy to decide which of the distribution we are working with.  The thick gray shows the median on Violin,
#
# Bar plot-  is more better in use for categorical dataset.

# %% [markdown]
# streamlines the amount of code to write and create matplotlib visualization
# provides specialzed support for using categorical variables
# has functions to examine relationships between multiple variables

# %%
df =pd.DataFrame()
df['x']= np.arange(0,10,1)
df['y']= df['x']**2
df
# Out:
#    x   y
# 0  0   0
# 1  1   1
# 2  2   4
# 3  3   9
# 4  4  16
# 5  5  25
# 6  6  36
# 7  7  49
# 8  8  64
# 9  9  81

# %%
plt.plot(df['x'],df['y'])

# %%
df.plot('x', 'y')
# Out:
# <AxesSubplot:xlabel='x'>

# %%
sns.lineplot(df['x'],df['y'])
# Out:
# /opt/anaconda3/envs/kittycat/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
help(sns.lmplot)
# Out:
# Help on function lmplot in module seaborn.regression:
#
# lmplot(*, x=None, y=None, data=None, hue=None, col=None, row=None, palette=None, col_wrap=None, height=5, aspect=1, markers='o', sharex=True, sharey=True, hue_order=None, col_order=None, row_order=None, legend=True, legend_out=True, x_estimator=None, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None, seed=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=True, x_jitter=None, y_jitter=None, scatter_kws=None, line_kws=None, size=None)
#     Plot data and regression model fits across a FacetGrid.
#
#     This function combines :func:`regplot` and :class:`FacetGrid`. It is
#     intended as a convenient interface to fit regression models across
#     conditional subsets of a dataset.
#
#     When thinking about how to assign variables to different facets, a general
#     rule is that it makes sense to use ``hue`` for the most important
# ...

# %%
# This is without regrssion line
sns.lmplot('x', 'y', data = df,fit_reg =False)# YOU CAN ALSO WRITE THE NAME OF YOUR DATASET WITH DATA BUT WITH DATA, IT MAKES IT LOOK NICE
# Out:
# /opt/anaconda3/envs/kittycat/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('x', 'y', data = df) # this is with regression line.

# %%
data = pd.read_csv('vehicles.csv')
data.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %% [markdown]
# BOX PLOT

# %% [markdown]
# In matplotlib

# %%
data.boxplot(column = 'Combined MPG')
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column = ['Combined MPG', 'Highway MPG'])
# Out:
# <AxesSubplot:>

# %%
print(data['Combined MPG'].mean())
print(data['Combined MPG'].median())
# Out:
# 19.92932242990654
# 19.0

# %% [markdown]
# # In seaborn

# %%
sns.boxplot('Combined MPG', data= data)
# Out:
# /opt/anaconda3/envs/kittycat/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Combined MPG'>

# %%
sns.boxplot('Combined MPG','Highway MPG', data= data)
# Out:
# /opt/anaconda3/envs/kittycat/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Combined MPG', ylabel='Highway MPG'>

# %% [markdown]
# # VIOLINPLOT

# %%
sns.violinplot('Combined MPG', data= data)
# Out:
# /opt/anaconda3/envs/kittycat/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Combined MPG'>

# %%
sns.violinplot('Combined MPG','Highway MPG', data= data)
# Out:
# /opt/anaconda3/envs/kittycat/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Combined MPG', ylabel='Highway MPG'>

# %% [markdown]
# # HISTOGRAM

# %% [markdown]
# In matplotlib

# %%
plt.hist(data['Combined MPG'])
# Out:
# (array([6.3800e+02, 8.4990e+03, 1.5512e+04, 7.9320e+03, 2.4160e+03,
#         6.3600e+02, 2.1000e+02, 6.5000e+01, 3.3000e+01, 1.1000e+01]),
#  array([ 7. , 11.9, 16.8, 21.7, 26.6, 31.5, 36.4, 41.3, 46.2, 51.1, 56. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# IN SEABORN

# %%
# I made a mistake to name it displot and it came out cool hahah
sns.displot(data['Combined MPG'], bins= 50)

# %%
sns.distplot(data['Combined MPG'], bins= 50)
# Out:
# /opt/anaconda3/envs/kittycat/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Combined MPG', ylabel='Density'>

# %% [markdown]
# # BAR PLOT

# %%
fig = sns.barplot('Highway MPG', 'Fuel Type', data= data).get_figure()
fig.savefig('example.png')
# Out:
# /opt/anaconda3/envs/kittycat/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
